# %%
# Mount Google Drive (Alihan)
from google.colab import drive
drive.mount('/content/drive')

import os

# Change to a specific directory
os.chdir('/content/drive/MyDrive/Okul/Eğitim/Ders/5. Dönem/YZV 303E - Deep Learning/Project/Colab')

# Verify the current working directory
print("Current Directory:", os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Current Directory: /content/drive/MyDrive/Okul/Eğitim/Ders/5. Dönem/YZV 303E - Deep Learning/Project/Colab

# %%
# Mount Google Drive (Topcu)
from google.colab import drive
drive.mount('/content/drive')

import os

# Change to the shared folder
# Adjust the path to where the shared folder shortcut was added in their Drive
os.chdir('/content/drive/My Drive/YZV 303E - Deep Learning/Project/Colab')

# Verify the current working directory
print("Current Directory:", os.getcwd())

# %% [markdown]
# ### Download image link dataset (TSVs) from Unsplash

# %%
# Download TSVs from Unsplash

# !wget -O "/content/drive/MyDrive/Okul/Eğitim/Ders/5. Dönem/YZV 303E - Deep Learning/Project/data/Unsplash/latest_unsplash_lite.zip" "https://unsplash.com/data/lite/latest"
# !unzip "/content/drive/MyDrive/Okul/Eğitim/Ders/5. Dönem/YZV 303E - Deep Learning/Project/data/Unsplash/latest_unsplash_lite.zip" -d "/content/drive/MyDrive/Okul/Eğitim/Ders/5. Dönem/YZV 303E - Deep Learning/Project/data/Unsplash/"
# !rm "/content/drive/MyDrive/Okul/Eğitim/Ders/5. Dönem/YZV 303E - Deep Learning/Project/data/Unsplash/latest_unsplash_lite.zip"

import os
directory = "/content/drive/MyDrive/Okul/Eğitim/Ders/5. Dönem/YZV 303E - Deep Learning/Project/data/Unsplash/"

for filename in os.listdir(directory):
    if filename.endswith(".tsv000"):
        base = os.path.splitext(filename)[0]  # Get the base name
        new_name = base + ".tsv"
        os.rename(os.path.join(directory, filename), os.path.join(directory, new_name))
        print(f"Renamed: {filename} to {new_name}")

import pandas as pd

file_path = '../data/Unsplash/photos.tsv'

df = pd.read_csv(file_path, sep='\t')
# Display the first few rows of the DataFrame
df.head()

# %% [markdown]
# ### Download images and split into L, A, B channels

# %%
# Download all images as RGB and create L, A, B channel images

import os
import cv2
import requests
import pandas as pd
from io import BytesIO
from PIL import Image
from datetime import datetime
import numpy as np

# Define paths
BASE_DIR = "../data/Unsplash/Images"
RGB_DIR = os.path.join(BASE_DIR, "RGB")
L_DIR = os.path.join(BASE_DIR, "L")
A_DIR = os.path.join(BASE_DIR, "A")
B_DIR = os.path.join(BASE_DIR, "B")
TSV_PATH = os.path.join(BASE_DIR, "image_links.tsv")
DOWNLOADED_LOG = os.path.join(BASE_DIR, "downloaded_images.tsv")
FAILED_LOG = os.path.join(BASE_DIR, "failed_images.tsv")  # New TSV for failed images

# Create necessary directories
os.makedirs(RGB_DIR, exist_ok=True)
os.makedirs(L_DIR, exist_ok=True)
os.makedirs(A_DIR, exist_ok=True)
os.makedirs(B_DIR, exist_ok=True)

# 1. Load and filter original data
original_df = pd.read_csv("../data/Unsplash/photos.tsv", sep="\t")

# Keep only required columns
new_df = original_df[['photo_id', 'photo_image_url', 'ai_description']]
new_df.to_csv(TSV_PATH, sep="\t", index=False)

# Check if image is grayscale
def is_grayscale(description):
    return "grayscale" in str(description).lower()

# Log downloaded image
def log_download(photo_id):
    if not os.path.exists(DOWNLOADED_LOG):
        with open(DOWNLOADED_LOG, 'w') as f:
            f.write("image_id\tdownloaded_at\n")

    with open(DOWNLOADED_LOG, 'a') as f:
        f.write(f"{photo_id}\t{datetime.now()}\n")

# Log failed image
def log_failure(photo_id):
    if not os.path.exists(FAILED_LOG):
        with open(FAILED_LOG, 'w') as f:
            f.write("image_id\tfailed_at\n")

    with open(FAILED_LOG, 'a') as f:
        f.write(f"{photo_id}\t{datetime.now()}\n")

# Resume functionality: Find last downloaded ID
def get_last_downloaded_id():
    if not os.path.exists(DOWNLOADED_LOG):
        return None
    log_df = pd.read_csv(DOWNLOADED_LOG, sep="\t")
    if not log_df.empty:
        return log_df['image_id'].iloc[-1]
    return None

# Process a single image
def process_image(row):
    photo_id = row['photo_id']
    image_url = row['photo_image_url']

    if is_grayscale(row['ai_description']):
        print(f"Skipping grayscale image: {photo_id}")
        return None

    try:
        # Download the image
        response = requests.get(f"{image_url}?w=256&h=256&fit=crop", stream=True)
        response.raise_for_status()

        # Convert to RGB using PIL
        image = Image.open(BytesIO(response.content)).convert("RGB")
        image_np = np.array(image)  # Convert to NumPy array

        # Convert directly from RGB to LAB
        lab_image = cv2.cvtColor(image_np, cv2.COLOR_RGB2LAB)
        L_channel, A_channel, B_channel = cv2.split(lab_image)

        # Save the RGB image
        cv2.imwrite(os.path.join(RGB_DIR, f"{photo_id}.png"), cv2.cvtColor(image_np, cv2.COLOR_RGB2BGR))

        # Save the LAB channels
        cv2.imwrite(os.path.join(L_DIR, f"{photo_id}.png"), L_channel)
        cv2.imwrite(os.path.join(A_DIR, f"{photo_id}.png"), A_channel)
        cv2.imwrite(os.path.join(B_DIR, f"{photo_id}.png"), B_channel)

        # Log the download
        log_download(photo_id)
        print(f"Successfully processed image: {photo_id}")

    except Exception as e:
        # Log failure and continue
        print(f"Failed to process image {photo_id}: {e}")
        log_failure(photo_id)

# Main function
def download_images():
    # Load image links TSV
    image_links_df = pd.read_csv(TSV_PATH, sep="\t")

    # Find the last downloaded ID
    last_id = get_last_downloaded_id()
    start_index = 0

    if last_id:
        print(f"Resuming from last downloaded ID: {last_id}")
        start_index = image_links_df.index[image_links_df['photo_id'] == last_id].tolist()[0] + 1
    else:
        print("Starting download from the beginning.")

    # Process images starting from the determined index
    for _, row in image_links_df.iloc[start_index:].iterrows():
        process_image(row)

    print("All images processed successfully!")

# Run the script
if __name__ == "__main__":
    download_images()
# Out:
# Resuming from last downloaded ID: NsvzdXtvyio
# Successfully processed image: k2DVsB4hTBQ
# Successfully processed image: lhPLeHgox9Q
# Successfully processed image: WT_nZUfAmBc
# Successfully processed image: byq4tkp1nmg
# Successfully processed image: s-4i34Z07To
# Successfully processed image: DPiWUyqyUNE
# Successfully processed image: HwQlPnLtaN4
# Successfully processed image: g0wj801aNio
# Successfully processed image: 0EOzs194BXQ
# Successfully processed image: 9XzyEzPAHMI
# Successfully processed image: NCFDCgj-2mM
# Successfully processed image: auPmvdEJQ-4
# Successfully processed image: E_H-5Cyxjfc
# Successfully processed image: 0yeDc5fOgu4
# Successfully processed image: 2Ka0oKSMxVE
# Successfully processed image: Oo2f26k1vFY
# Successfully processed image: s9u9o-BpxZ0
# Successfully processed image: 4UBHkX2rlMY
# Successfully processed image: 4D7-9lVUvNY
# Successfully processed image: WA1Lpc7iFNw
# Successfully processed image: em7gIbjEL0I
# Successfully processed image: _ypd6fZlJq4
# Successfully processed image: vU1FGBXfX7c
# Successfully processed image: h_sm9J-EpA4
# Successfully processed image: UgKZsDakCRo
# Successfully processed image: RIwKjm3TVMU
# Successfully processed image: wNSSdNx932E
# Successfully processed image: sV7_2anjhU8
# Successfully processed image: eNi9DGpVYWk
# Successfully processed image: N7-uM2wo61k
# Successfully processed image: ehsAbwSdS94
# Successfully processed image: jKiu7sPW7SE
# Successfully processed image: ktwf6kExFAw
# Successfully processed image: lzMwvo-tUwU
# Successfully processed image: TLLjBr_8thQ
# Successfully processed image: bNVUIsvteK8
# Successfully processed image: cYeAL0F2ei8
# Successfully processed image: lO-0vrsPjjg
# Successfully processed image: YUBNuiuIGU0
# Successfully processed image: gaGHZPrgA-I
# Successfully processed image: RCWdP4sQVuQ
# Successfully processed image: OmelL9tVVno
# Successfully processed image: SJK01GnfZG4
# Successfully processed image: 27GGDSsuQQg
# Successfully processed image: bdHUUnDHtcE
# Successfully processed image: KTIVMMOXNu8
# Successfully processed image: tIgtXoWyOhE
# Successfully processed image: YuicvRyGweo
# Successfully processed image: ZdONCKuFCIQ
# Successfully processed image: jjrFZYBpl0U
# Successfully processed image: m6eMa9yGa6Q
# Successfully processed image: JGw5EEqjeNE
# Successfully processed image: o7vQxMeVepo
# Successfully processed image: rWBvO8-lh3o
# Successfully processed image: _xpOzVgCCMs
# Successfully processed image: KGGwZZ7e9F4
# Successfully processed image: BV08_m0gzvQ
# Successfully processed image: _zkkEn64jfU
# Successfully processed image: N5-Sm8os5Cs
# Successfully processed image: CdbNtePkCSE
# Successfully processed image: SHIDPK_URIU
# Successfully processed image: ZeM0C96lmdU
# Successfully processed image: hEceQrBaIiE
# Successfully processed image: ELISIYFi-ws
# Successfully processed image: RoTyXO1m0wo
# Successfully processed image: KOAJOeZwOxA
# Successfully processed image: NAozxjw5Wqo
# Successfully processed image: EcsdAlwpmrw
# Successfully processed image: w3gsjym40f4
# Successfully processed image: _gRwUCWDf8Y
# Successfully processed image: FNLpmjV1rOY
# Successfully processed image: 5mIcH3q7tIk
# Successfully processed image: bZQ3dkrVi9E
# Successfully processed image: haf-Wo-4Qd8
# Successfully processed image: IkzHn_bWyr4
# Successfully processed image: CkCafqoOlPg
# Successfully processed image: vnY8Xl4RhD4
# Successfully processed image: 9rC6w_49RSE
# Successfully processed image: mYbCwgRYMXw
# Successfully processed image: VVi6wHOJFhk
# Successfully processed image: ww2S2eKgbKE
# Successfully processed image: Ay67yB6vmF8
# Successfully processed image: IHQDaOrEsAo
# Successfully processed image: NljdMbT3s30
# Successfully processed image: LCTm9Q6Woo8
# Successfully processed image: vBwbe7mARBc
# Successfully processed image: ZCnvMXqa9ho
# Successfully processed image: ui_izgPOwKY
# Successfully processed image: -5WWw6DeQ8w
# Successfully processed image: 8J0Y41hXfH0
# Successfully processed image: CW_B41pRRP4
# Successfully processed image: GVaRGYa_cmk
# Successfully processed image: 1whm4uDjX4w
# Successfully processed image: aGmLdzQ9TxY
# Successfully processed image: zcDXfKNAMHc
# Successfully processed image: oogJpviGhO0
# Successfully processed image: 7CQFCHoFL-o
# Successfully processed image: WRCYfh_7mmw
# Successfully processed image: VjKVgvHyY50
# Successfully processed image: oOxpcbjSHx8
# Successfully processed image: dONpUNwqjBI
# Successfully processed image: tLUgvVaCQnY
# Successfully processed image: Vy7VdLXh_nU
# Successfully processed image: UiUWb5caNis
# Successfully processed image: LmqySFs3TQQ
# Successfully processed image: z7CyPm9uKmA
# Successfully processed image: Gne1Y7JvwiI
# Successfully processed image: 4kkYkFNfJV8
# Successfully processed image: oQbyh3VKHnM
# Successfully processed image: Qxzn3Fwy3qU
# Successfully processed image: 1x9ElmBT7t0
# Successfully processed image: M6a5BrXz1gU
# Successfully processed image: My1oqpgAf8s
# Successfully processed image: oytzTWCHoAg
# Successfully processed image: mKFCS2ti3o0
# Successfully processed image: jXFooDkFZRY
# Successfully processed image: A9WWcz9IoPE
# Successfully processed image: 03E-nfoFKtE
# Successfully processed image: ZhRkvdDgK78
# Successfully processed image: a5kLiYV4ymM
# Successfully processed image: RqKle-djsbQ
# Successfully processed image: ZsvV6tcEQLQ
# Successfully processed image: 5wlMDWjGBJ4
# Successfully processed image: RFSIWpa5hcM
# Successfully processed image: i-toUzanTJE
# Successfully processed image: ZhMVRbv9GSc
# Successfully processed image: K-tnyWHS504
# Successfully processed image: JtVkmKQ1FQI
# Successfully processed image: GYIxdUFEkX8
# Successfully processed image: Rs1pUtbuiQQ
# Successfully processed image: _jX4K7F03uQ
# Successfully processed image: DWkWeFN-I9Y
# Successfully processed image: 3_KN64um8kM
# Successfully processed image: 7ykoAE-7Bxo
# Successfully processed image: 3m_Bw26L4XE
# Successfully processed image: IFtJKM6mTSk
# Successfully processed image: z6A_uGtY51M
# Successfully processed image: q-mqF5F31CU
# Successfully processed image: 7b9BA_BFgcM
# Successfully processed image: 5Uov8YWmoso
# Successfully processed image: 0cIzR3h_w7E
# Successfully processed image: rR3RPRDhjwM
# Skipping grayscale image: HULk8KYNJsU
# Successfully processed image: -HvoDBAX8hg
# Successfully processed image: hmkfNT1EsBs
# Successfully processed image: cLwQssZtPQA
# Successfully processed image: -VIIUPt7h9E
# Successfully processed image: yjCD8LjOfmc
# Successfully processed image: JlT3mACrdRI
# Successfully processed image: ljoFhMwov8U
# Successfully processed image: 47g-IDWhlCc
# Successfully processed image: eXbgRmq_DHw
# Successfully processed image: Wu2xSpzGjXU
# Successfully processed image: 9yPrlr03AIU
# Successfully processed image: LWRyc9XSNLU
# Successfully processed image: 1C_fT-mKdDM
# Successfully processed image: aZvsnQarMzA
# Successfully processed image: rD1_nrA5_1U
# Successfully processed image: wRnaQms8n14
# Successfully processed image: L-fsASSJ29c
# Successfully processed image: TeucWzHYUYk
# Successfully processed image: D5TmUdYwi3Q
# Successfully processed image: OWRn9UnvhyA
# Successfully processed image: 7RwzIb8fWlk
# Successfully processed image: tGMnVwbUT_o
# Successfully processed image: fMrd9I3sOEc
# Successfully processed image: ixMkxeQj1Zk
# Successfully processed image: qsgZMnf0Uyc
# Successfully processed image: fhBG1WkevcY
# Successfully processed image: ycJHJGRgdmI
# Successfully processed image: OZe0e6Hwkkw
# Successfully processed image: Ti8NogDRMBs
# Successfully processed image: b203hfveE-I
# Successfully processed image: D2nNU7CBkeI
# Successfully processed image: he_GLVSR4sU
# Successfully processed image: 9bn3OmplMVg
# Successfully processed image: SRoqaeEb7Nk
# Successfully processed image: RNM1ULC0LLU
# Successfully processed image: ZIDL2-88SEI
# Successfully processed image: gVpKmdfiHbk
# Successfully processed image: 4QYTLcub_8E
# Successfully processed image: pek1LJUsSvM
# Successfully processed image: OxHszlgpyaE
# Successfully processed image: KIJYJLQlylI
# Successfully processed image: olFTlUK3sCo
# Successfully processed image: yjQB-aWPvq8
# Skipping grayscale image: Ik2OLmVo2UE
# Successfully processed image: hh4G-19JQAc
# Successfully processed image: iPufjnRsYe0
# Successfully processed image: qTN7y0IyG4w
# Successfully processed image: BDFWZ3fLxrg
# Successfully processed image: 7sW1wUYj4mA
# Successfully processed image: rnM68YuWNFw
# Successfully processed image: 8zZf1FEaiSA
# Successfully processed image: tzWhnsJjg1Y
# Successfully processed image: cyyMuBsS1A4
# Successfully processed image: usvMFvq1Z54
# Successfully processed image: MYQ_8Wbfq5g
# Successfully processed image: UocBRAST7es
# Successfully processed image: t_Vy7D51gdE
# Successfully processed image: GkFYzS3v4bY
# Successfully processed image: cHP9WBFKm9o
# Successfully processed image: NONCz9w8X3Y
# Successfully processed image: X6NTotfCiHU
# Successfully processed image: nt4eH8aHOB8
# Successfully processed image: MbweoXr6U0Q
# Successfully processed image: k7Vcn--BLfY
# Successfully processed image: MXJ3QUxhNrY
# Successfully processed image: iHeymraGXvk
# Successfully processed image: 4n1CicmdXEM
# Successfully processed image: q6UtqGETjQE
# Successfully processed image: BkD4ZWs818c
# Successfully processed image: Qu8R-NNSuhU
# Successfully processed image: Wq19-E0vGj0
# Successfully processed image: d06lt8UI7Ao
# Successfully processed image: H7JiEU8Slnw
# Successfully processed image: JlagcSUKyTw
# Skipping grayscale image: 1BuzFn7GT5s
# Successfully processed image: p6hzGvEXSoQ
# Successfully processed image: M94JgUk9Ebc
# Successfully processed image: j5JMA4Fjq4c
# Successfully processed image: WocopbxkEyQ
# Successfully processed image: 10B8fyjCf68
# Successfully processed image: K-zFlq3gMBU
# Successfully processed image: yOkJPDCI_rI
# Successfully processed image: 7trjwhGMwsM
# Successfully processed image: bWb758kLnGQ
# Successfully processed image: _KdARYO5PI8
# Successfully processed image: 8Yf_m-_HoUk
# Successfully processed image: iBouqMX0Jdw
# Successfully processed image: FGyk4UGUyzE
# Successfully processed image: zUTalRZ7tGE
# Successfully processed image: eMdHivuHFoA
# Successfully processed image: qKVngcBKeFk
# Successfully processed image: ZzqM2YmqZ-o
# Successfully processed image: htAyoWqrXww
# Successfully processed image: 7FLh300YONc
# Successfully processed image: F7HGqkkMYAU
# Successfully processed image: vIqxsp0_p1g
# Successfully processed image: RXq_71ICIcg
# Successfully processed image: FpaxwZ4apss
# Successfully processed image: DHMcRjvBmdk
# Successfully processed image: LH-oDgQW2CQ
# Successfully processed image: RJDZBhPzlDg
# Successfully processed image: xL66l--msXU
# Successfully processed image: _cb5MjNG3DI
# Successfully processed image: c3qvF4WR0Rw
# Skipping grayscale image: qJmfb_wWXhw
# Successfully processed image: JiphyElpixM
# Successfully processed image: Y31bDcS9me0
# Successfully processed image: fi9PSKk7UyE
# Successfully processed image: R9EF0TmnFTc
# Successfully processed image: sYXkoF-W5hQ
# Successfully processed image: yvQgA1IxuIE
# Successfully processed image: E2SGMyG5vLw
# Successfully processed image: 4JLB7Bp8W_w
# Successfully processed image: nEJ50HJpQRM
# Successfully processed image: fEHkt3GgCWA
# Successfully processed image: hB_yapuPaIs
# Successfully processed image: YEwxD1D9yc4
# Successfully processed image: fDV3geJ2HwM
# Successfully processed image: is9Uq0eN7aI
# Skipping grayscale image: c4n-4SSyZ9g
# Successfully processed image: lMSozvjQ_4g
# Successfully processed image: e0BNPHPJDjg
# Successfully processed image: ZbvHaiUwVfo
# Successfully processed image: _pX9jS9eI4Q
# Successfully processed image: bCqZor3BOu0
# Successfully processed image: IdvPe1OpFek
# Successfully processed image: pnp2Vbs59t8
# Successfully processed image: -S3IU3Uqvi8
# Successfully processed image: -4YbaM07U44
# Successfully processed image: _f2m3mEkaaU
# Successfully processed image: bk4hN4Jvnac
# Successfully processed image: MnhfamCWs6s
# Successfully processed image: iPj9S8wX7Ao
# Successfully processed image: z7vwbDUrlq4
# Successfully processed image: oQmKteV2yBA
# Successfully processed image: lEBDlbXLEgs
# Successfully processed image: z7tQUhBVOrY
# Successfully processed image: eD-yqMiiHP0
# Successfully processed image: MPYUwhE8Jjs
# Successfully processed image: pc00EDmxodI
# Successfully processed image: dbRzRdHfXho
# Successfully processed image: PZEBRwmvNxE
# Successfully processed image: 2V3OzQZAIPs
# Successfully processed image: 7AbabK9lsB4
# Successfully processed image: 8sQoBzPNdpQ
# Successfully processed image: Cny5kzA3mEU
# Successfully processed image: gtabImSzH-g
# Successfully processed image: i3GE3y8F0jg
# Successfully processed image: 7y-zM8nppxk
# Successfully processed image: Y_gpWZKXYjY
# Successfully processed image: 795KLb6DI7E
# Successfully processed image: g-VWR0UN4kQ
# Successfully processed image: 00taym-piCM
# Successfully processed image: lKkLmtZ5EHs
# Successfully processed image: 16EFEq4gphQ
# Successfully processed image: 2CHn_UAdp5Q
# Successfully processed image: izOae89oonk
# Successfully processed image: WYh5kxf0Dy4
# Successfully processed image: niRHgPRSaw4
# Successfully processed image: zH9dWD_KttY
# Successfully processed image: G9zkaRjVOS4
# Successfully processed image: SUgjIT8-eOk
# Successfully processed image: A9kYGeJkMZE
# Successfully processed image: lT2c4pxkP78
# Successfully processed image: Tig3jRhWrpE
# Successfully processed image: cBYOgEBN9BY
# Successfully processed image: fJbUyfW1Clo
# Successfully processed image: pHilcWj_NHY
# Successfully processed image: Jgdpgvo6fqE
# Successfully processed image: AXaLtJP4FmM
# Successfully processed image: 19IdBsV5ofg
# Successfully processed image: -YCNTEFKoYI
# Successfully processed image: bKoH-R2BS1o
# Successfully processed image: Obyt4h4M5iY
# Successfully processed image: uq9uAq3cS2Y
# Successfully processed image: rmmU1k1hb08
# Successfully processed image: Rwz-jGQ1Tsk
# Successfully processed image: 6nrE8WMLCMA
# Successfully processed image: VS8suHoZ8KE
# Successfully processed image: gZltlzPun9c
# Successfully processed image: RatxiOcaMZo
# Successfully processed image: Kj3DvPqzBDw
# Successfully processed image: K_SzMtxTmtg
# Successfully processed image: l4VCf72WlyY
# Successfully processed image: 7boYy26CGMQ
# Successfully processed image: qNPwSVIMgD0
# Successfully processed image: CApkiAlDSdo
# Successfully processed image: EbLX7oRo4vI
# Successfully processed image: iZoB9tBHJfc
# Successfully processed image: C8FiSfPh8IA
# Successfully processed image: 0ytwNH74s3A
# Successfully processed image: 0H92ha6c9SI
# Successfully processed image: mSL1shtsWFU
# Successfully processed image: qk6CnpKNmVw
# Successfully processed image: 1Gy6L3iJyUI
# Successfully processed image: Rj2Xuc6-cd0
# Successfully processed image: ZLjrk4UjPvE
# Successfully processed image: dld1xhMdpos
# Successfully processed image: ydS1df6jm8U
# Successfully processed image: nsHGeZlyd8U
# Successfully processed image: 9tk7FnbRevs
# Successfully processed image: wxKsq4LLEDM
# Successfully processed image: piJlXYXJljI
# Successfully processed image: 4ykeSff3dMc
# Successfully processed image: 6rL4T_bLUVk
# Successfully processed image: KTA83MjaeNM
# Successfully processed image: rq6tkSvaPUc
# Successfully processed image: ymOROKFl8tE
# Successfully processed image: Ey1CHKvnShc
# Successfully processed image: rR1_WcIXlBM
# Successfully processed image: iMVzDFNyAUY
# Successfully processed image: upT9R6CO-Hc
# Successfully processed image: F1OjCxOlj8Q
# Successfully processed image: cJDnWq3PKfU
# Successfully processed image: 8pizdZJS3nE
# Successfully processed image: iA0a8iIUFlM
# Successfully processed image: pXKewwt4xLk
# Successfully processed image: neyB-55sC_0
# Successfully processed image: jgicMx7vd58
# Successfully processed image: u3XMyl-4OSY
# Successfully processed image: BVFc_M6_KoU
# Successfully processed image: o51TCXsqCh4
# Successfully processed image: hcoUSNdX1Ho
# Successfully processed image: 5jVXWpYsB_M
# Successfully processed image: 72vLY-QMd3w
# Successfully processed image: lpu2T4Kts0A
# Successfully processed image: fHK6kIQmtTw
# Successfully processed image: TQGpLw48VsU
# Successfully processed image: u26M0jqr-QA
# Successfully processed image: VouUERkgtzM
# Successfully processed image: fNPzcLbeIqA
# Successfully processed image: CPIQfMbSjmM
# Successfully processed image: HsCvG7kHeX0
# Successfully processed image: MKeBSjTFf7A
# Successfully processed image: Q9cb64SF3pQ
# Successfully processed image: knvrzah30jo
# Successfully processed image: 6xTKw5ufGTY
# Successfully processed image: zi72GAIX02s
# Successfully processed image: Npc9ZQdYMvQ
# Successfully processed image: 6IEMJfojgOI
# Successfully processed image: brKCHU0Xo5s
# Successfully processed image: shdHATuLZAs
# Successfully processed image: 4J16oO4MmXs
# Successfully processed image: 4foObuXP7fY
# Successfully processed image: imX1IGh-A9Q
# Successfully processed image: HPTHeRbINXw
# Successfully processed image: xLHhmLzCeMs
# Successfully processed image: mDHMoOuDe34
# Successfully processed image: YbONK6x4ni8
# Successfully processed image: uButEWo8xs4
# Successfully processed image: N3rPbAm9tN0
# Successfully processed image: YDDFBz0s7tA
# Successfully processed image: XPm4iCJKyhI
# Successfully processed image: hSh_X3kJ4bI
# Successfully processed image: 2mqbXtsgP7g
# Successfully processed image: TpnStdTDVCI
# Successfully processed image: -h53wDV4SF0
# Successfully processed image: 37asHHaTc_E
# Successfully processed image: HNdKjlLGgIQ
# Successfully processed image: t7htLG6DkzE
# Successfully processed image: _7a8Y0FNeZE
# Successfully processed image: lWfmq1VdNVY
# Successfully processed image: 0-YcgK37WMU
# Successfully processed image: uvd8VjR7qoU
# Successfully processed image: ROd5LZWRXmg
# Successfully processed image: aErJZckIlYA
# Successfully processed image: pkfwwofpNUw
# Successfully processed image: -z0M-aBEd1g
# Successfully processed image: fRdi0Ed-gy0
# Successfully processed image: bMwZche8JCw
# Successfully processed image: 06kkjJ98Izo
# Successfully processed image: 49ktllPyN9U
# Successfully processed image: Nzy_Fm6gZKI
# Successfully processed image: i-oQ_7vTHcE
# Successfully processed image: rqOIV-eTBR4
# Successfully processed image: 2XlB5L33Asw
# Successfully processed image: oOh-UMR1Vdc
# Successfully processed image: QSjl2Qwz5uw
# Successfully processed image: 1eReB1OKOr0
# Successfully processed image: n6hzRDQ9CM8
# Successfully processed image: LAyG1M2wA-k
# Successfully processed image: MP30frmCUrs
# Successfully processed image: tMkEedbhuDo
# Successfully processed image: f4RAhPf7ncI
# Successfully processed image: EbWDDnbnBHU
# Successfully processed image: 15YDf39RIVc
# Successfully processed image: aZ4OSja8LD0
# Successfully processed image: wuHPFRWtDLI
# Skipping grayscale image: uDUiRS8YroY
# Successfully processed image: czhIG-jAB8I
# Successfully processed image: ghP1Pf97A3Q
# Successfully processed image: HE8FItkJqCs
# Successfully processed image: -oXRq-N5btU
# Successfully processed image: LqVDXObLTlk
# Successfully processed image: BDuIPkFGjxs
# Successfully processed image: Qp2H0q9Py5s
# Successfully processed image: IWexwTUOyEs
# Successfully processed image: Qkr7fS-_P4M
# Successfully processed image: OL0N29kz7II
# Successfully processed image: J4fcg3i1rwg
# Successfully processed image: eYbDKg2O7Lo
# Successfully processed image: 0arBExmGkwM
# Successfully processed image: vhTFZz2rnCA
# Successfully processed image: i9LQlWzfZyc
# Successfully processed image: Apk5a8ztFwc
# Successfully processed image: Z_qfc16mwX8
# Successfully processed image: chbXE4o0ryU
# Successfully processed image: X7UR0BDz-UY
# Successfully processed image: CW84zI5DxtM
# Successfully processed image: JYeDR7bwVBM
# Successfully processed image: C5A1ZQmNd9c
# Successfully processed image: 311t51Tz1Tk
# Successfully processed image: eGSjyhy6KmI
# Successfully processed image: OzD_vkpMM5Y
# Successfully processed image: LH7-_hr5PbM
# Successfully processed image: HQ1eQRQkjI8
# Successfully processed image: 13JMpnyS7Ls
# Successfully processed image: pEOaSft8ahM
# Successfully processed image: GRIRnUHkzJY
# Successfully processed image: 8rmYDezMIE4
# Successfully processed image: CpppxlHFa-8
# Successfully processed image: O-XriFhXMw0
# Successfully processed image: pH6vl8AHOjI
# Successfully processed image: RjcAkBw8WBw
# Successfully processed image: qkaCOR_R-Xw
# Successfully processed image: XWi-_Pv4rp8
# Successfully processed image: H-WiIcJ1Xdk
# Successfully processed image: QjR_snVQn4c
# Successfully processed image: kAiyiesI_Kk
# Successfully processed image: 2g1gyEumIrE
# Successfully processed image: ZHYAOcS_nfQ
# Successfully processed image: woiwBMqfJcA
# Successfully processed image: ZVM4AlMU6IY
# Successfully processed image: y_VSZO-taAE
# Successfully processed image: -zmrmCYFveg
# Successfully processed image: bAja1bOVoxM
# Successfully processed image: lVpEY1BOTuM
# Successfully processed image: mtWegPVdaH4
# Successfully processed image: yhiZm7vYXaM
# Successfully processed image: gGI_UtxcNkk
# Successfully processed image: KXq1wGn_OXI
# Successfully processed image: TnrpxHeN3OM
# Successfully processed image: htsxWj5YaaM
# Successfully processed image: T_Qe4QlMIvQ
# Successfully processed image: 2TlKofper84
# Successfully processed image: mVUxdi7yOOI
# Successfully processed image: tVRIFEnO9pM
# Successfully processed image: D8oN3jRgPzc
# Successfully processed image: lqs4zehTcrk
# Successfully processed image: H_oCwUI9E1o
# Successfully processed image: -ZYkhqecXt0
# Successfully processed image: 1fJ7DqrrXs0
# Successfully processed image: 2OuUx9VDl74
# Successfully processed image: qge7llyp7cc
# Successfully processed image: tmvh6H7GSA0
# Successfully processed image: DlsOa5moK4w
# Successfully processed image: 6-C0VRsagUw
# Successfully processed image: 6p6WDodvR2Y
# Successfully processed image: 67UdujKL7TE
# Successfully processed image: KM1M0Kk4Xtg
# Successfully processed image: x5LRxIZ5Lqk
# Successfully processed image: psIMdj26lgw
# Successfully processed image: dRQhhIdaCBU
# Successfully processed image: NrflUuJJK0I
# Successfully processed image: XA2OEcvrrP8
# Successfully processed image: WN8kSLy8KMQ
# Successfully processed image: MQz-tZEg8L8
# Successfully processed image: CpHNKNRwXps
# Successfully processed image: Glsblqe0N58
# Successfully processed image: 2aebgOyQ1hQ
# Successfully processed image: t0GpJ2cdJuo
# Successfully processed image: 2PMsTEWAfwU
# Successfully processed image: mNCFOaaLu5o
# Successfully processed image: I_giG67yP5Q
# Successfully processed image: V__yW0wQCOs
# Successfully processed image: vTftVP9jo_4
# Successfully processed image: pwP-EXdIQQY
# Successfully processed image: bDJOs9Th2GQ
# Successfully processed image: U-ROch-TGZg
# Successfully processed image: szmakgWdl78
# Successfully processed image: biyW-piLJ7Y
# Successfully processed image: kijHzOdUM7o
# Successfully processed image: QputIByOdAY
# Successfully processed image: SAB6LotG2PM
# Successfully processed image: 4mA9_5vbZ_s
# Successfully processed image: pODpVzUS-yA
# Successfully processed image: K2iw3JoxPrc
# Successfully processed image: fkfKa0E1muw
# Successfully processed image: tIUN8a9G0Kw
# Successfully processed image: CWUAen2vp-0
# Successfully processed image: yER6L9sRPXM
# Successfully processed image: X_yDmjSAH4g
# Successfully processed image: YQN-5gdd-yw
# Successfully processed image: GJBNrDXwmyg
# Successfully processed image: 7VNxh3nU2NU
# Successfully processed image: CSdcvzCoziM
# Successfully processed image: u2sYsHbb4YE
# Successfully processed image: a7T0PQol-6E
# Successfully processed image: OgVT4yfpIxk
# Successfully processed image: Vb03m4eY4LM
# Successfully processed image: gHXaANn_wXM
# Successfully processed image: _1rpqoEwUtw
# Successfully processed image: 1WhW787C2UE
# Successfully processed image: c19qlljAdjI
# Successfully processed image: FRVQ4P49YIs
# Successfully processed image: 8qXnX2T_3mo
# Successfully processed image: 5ckOdg-HQ0A
# Successfully processed image: J7rRzjba-kY
# Successfully processed image: XzFOfXOMq-4
# Successfully processed image: yNfDBAu_8wo
# Successfully processed image: xBsxXrsTpPE
# Successfully processed image: CGqTT1YSDdw
# Successfully processed image: nwROzyFBB64
# Successfully processed image: HgoEnDWOGrA
# Successfully processed image: uasc967z9fI
# Successfully processed image: 9F4qrNS4fCI
# Successfully processed image: GRLN5FC4cLg
# Successfully processed image: JTEi1fWSygE
# Successfully processed image: LZNnJ8XPIl8
# Successfully processed image: Syl05eRC0nA
# Successfully processed image: nz2hUsnlyLc
# Successfully processed image: mmrwj-VV17Q
# Successfully processed image: 8pgK9350lv4
# Successfully processed image: RmyQy67U3HY
# Successfully processed image: rQjbpvDtJoU
# Successfully processed image: UCrRNOrGtAE
# Successfully processed image: DsFnLlcnTok
# Successfully processed image: YbgPWfWlvkE
# Successfully processed image: EOxpS6yBQU4
# Successfully processed image: 7lUDryZFbbE
# Successfully processed image: KkCDC-sGKwQ
# Successfully processed image: sKJ7zSylUao
# Successfully processed image: JIF__24w3XA
# Successfully processed image: EafH-BTjj1Q
# Successfully processed image: 1NRIIzqbJls
# Successfully processed image: wn7Vdl8_yXc
# Successfully processed image: qem7xLMt1bU
# Successfully processed image: MsNoBrXCZto
# Skipping grayscale image: asgcv25s4bA
# Successfully processed image: wEgiJtlfzPc
# Successfully processed image: gmHVdAGe2EI
# Successfully processed image: dazjc3MXsDc
# Successfully processed image: CuRJWTssVvc
# Successfully processed image: KjutKKAHtsY
# Successfully processed image: 6Qjulv4ZayA
# Successfully processed image: h5Aenbzd_FA
# Successfully processed image: iibjsy2QFEE
# Successfully processed image: 2QhVSCUUK8Q
# Successfully processed image: x4CoNitOUKc
# Successfully processed image: gwTEUjUr7NY
# Successfully processed image: wyZi9MVqEdQ
# Successfully processed image: _Im6jh8P8nA
# Successfully processed image: dg5KvcVv7tU
# Successfully processed image: YcCTVdhPiw4
# Successfully processed image: zcWRhtwhkYw
# Successfully processed image: nGjGg9TVTGg
# Successfully processed image: JhRjjzLQsjc
# Successfully processed image: D_pbnIkHz1Y
# Successfully processed image: R2cWLl7yj1o
# Successfully processed image: AaB6qlzlgJs
# Successfully processed image: TSuGZ6_GMcs
# Successfully processed image: 5Mrcxnq3Nhg
# Successfully processed image: H5X-6weqoSo
# Successfully processed image: sH-ueXU68WM
# Successfully processed image: DqrKRxworhA
# Successfully processed image: C5mrwhFTEvY
# Successfully processed image: d7t7TjsBfpY
# Successfully processed image: eQaUlrIdgfA
# Successfully processed image: -xZqcyTBUSI
# Successfully processed image: -6_jB6qjwCQ
# Successfully processed image: ze7z6JENYVk
# Successfully processed image: kjbUGZyTSho
# Successfully processed image: 7x092PMauCg
# Successfully processed image: cu3m1FEYgL8
# Successfully processed image: RTUsoOh9e8M
# Successfully processed image: jE2oSbUBmrk
# Successfully processed image: ds7DVwunWZE
# Skipping grayscale image: LD8FhvuLiEA
# Successfully processed image: 5tUQrvZCyys
# Skipping grayscale image: dPnheC5ObaM
# Successfully processed image: NYUjk2l9eZE
# Successfully processed image: 9SYqx5Pfohs
# Successfully processed image: HUGWwCoOuz0
# Successfully processed image: Q4BHlxIuueM
# Successfully processed image: Fkvto-ziiYs
# Successfully processed image: -rshDVyLGxI
# Successfully processed image: TfM9PYTlXd8
# Successfully processed image: djV34LaV0OQ
# Successfully processed image: -BkZzidZIZg
# Successfully processed image: 4BvvvgTBObw
# Successfully processed image: m6iJEDrtk4I
# Successfully processed image: ZSjEf0EABqU
# Successfully processed image: m4b3fR6H8Vo
# Successfully processed image: r24Ms9a40e0
# Successfully processed image: iGX3Ba5oiQ4
# Successfully processed image: 0oCZLHIHBns
# Successfully processed image: RVEBa3RIXho
# Successfully processed image: BcD1vwoiaVo
# Successfully processed image: 8wV8bdQtmTo
# Successfully processed image: ssC6HHt6YEc
# Successfully processed image: 1fWwJOY49ow
# Successfully processed image: vnywo8u6d9c
# Successfully processed image: oNSvTtnNXEc
# Successfully processed image: FEGHUL4X_QQ
# Successfully processed image: qbCwcDfp_zw
# Successfully processed image: PO4mYiIjI9o
# Successfully processed image: z3Ywlxbxl5g
# Successfully processed image: TKy3LVuULQU
# Successfully processed image: zjfHfXykgDc
# Successfully processed image: V8nAvRXOklo
# Successfully processed image: GOJVZjuYIpY
# Successfully processed image: Ytw2Q3uBIi8
# Successfully processed image: 04VqnOF96V8
# Successfully processed image: qB3JKBvdOIA
# Skipping grayscale image: RdDTrEeDAV0
# Successfully processed image: i_NIPjipLMY
# Successfully processed image: B7ifBgRXDI4
# Successfully processed image: 3pR7d-tIRx8
# Successfully processed image: QDqZswbvIMg
# Successfully processed image: dSZQC7vVf5M
# Successfully processed image: 88PnZ92Tne4
# Successfully processed image: 9BqHgVjUniE
# Successfully processed image: 3bOcN07-iKo
# Successfully processed image: SHZ2C-ahVsw
# Successfully processed image: P2pGX2-zWNs
# Successfully processed image: Taj_pl51nU4
# Successfully processed image: ZvD7yhiV7BI
# Successfully processed image: KNczrAYAlZk
# Successfully processed image: TcNpLoAZkLI
# Successfully processed image: rSzOCn4CEfw
# Successfully processed image: bY3jN_teqtU
# Successfully processed image: YRUdoIElae0
# Successfully processed image: pO1jZ2i87fg
# Successfully processed image: WTSn3axynUk
# Successfully processed image: igOyiLcfLPs
# Successfully processed image: 2GyhJK267ok
# Successfully processed image: w-pEeDGN1w0
# Successfully processed image: Y-hfqtKiPX8
# Successfully processed image: FNmyzvykrew
# Successfully processed image: 624WUhcCm4w
# Successfully processed image: 90bGfiqwQ1M
# Successfully processed image: 3NoxefgvKfQ
# Successfully processed image: KDFxVFk7clU
# Successfully processed image: ypeC7Lu4MZ4
# Successfully processed image: kVwPcYo1Z3I
# Successfully processed image: aGHz9-KaO7Y
# Successfully processed image: gh0jQUTRX0c
# Successfully processed image: mSK5nNsAsLY
# Successfully processed image: cz3ls2zvc6U
# Successfully processed image: Qbn7_Nqs8WA
# Successfully processed image: cs6Omgsf0fU
# Successfully processed image: qHxwq_E7_yY
# Successfully processed image: 00W-OglEHdQ
# Successfully processed image: m7Uo3pnPGZI
# Successfully processed image: 8Br36-oRXDg
# Successfully processed image: 4OsJnt_qnlo
# Successfully processed image: 6uYGO15giQo
# Successfully processed image: AKlzQNrTxuw
# Successfully processed image: ZIlH22Jm7lM
# Successfully processed image: 6jhfleCGlSE
# Successfully processed image: pdzQ1cAdftk
# Successfully processed image: _2oDf30N6BY
# Successfully processed image: t--2nGjWLXc
# Successfully processed image: Sk1x2a-xKKY
# Successfully processed image: q0nDIxv3UI0
# Successfully processed image: s7nTU9i6whg
# Successfully processed image: rAP497AwNoU
# Successfully processed image: Y3GeJOgLKrA
# Successfully processed image: A6xAf8YumBI
# Successfully processed image: HKXKRUoy6yQ
# Skipping grayscale image: VpwPbBq7KWI
# Successfully processed image: Ap3AzCIYgE0
# Successfully processed image: _94wpXx6C4g
# Successfully processed image: yU-YlJxNDmQ
# Successfully processed image: KlfQcIMDsfU
# Successfully processed image: I3nHRNu3960
# Successfully processed image: KICyOWUj-ww
# Successfully processed image: t3nS2c_HRrM
# Successfully processed image: YY0vaZV7oIA
# Successfully processed image: i6epKg39R60
# Successfully processed image: j9a-kdKUwRI
# Successfully processed image: v-IdgVScjLM
# Successfully processed image: pU17ntS5_RM
# Successfully processed image: DWMDOv47CiQ
# Successfully processed image: IYvdGTWXxRM
# Successfully processed image: unVUb_sk05g
# Successfully processed image: KkEuqTss7u0
# Successfully processed image: QSnKwEKvMK8
# Successfully processed image: EWHWl6HfO1A
# Successfully processed image: 7DTKnOcXJB4
# Successfully processed image: mRFmtpv5wQQ
# Successfully processed image: Y4ybS881kKw
# Successfully processed image: ExgjQ-dXsv4
# Successfully processed image: K5pLGYJMHKk
# Successfully processed image: 7Tr62uzk45E
# Successfully processed image: lh0mqRUCrok
# Successfully processed image: tCbiE28dDvE
# Successfully processed image: a0V7k-HjAPc
# Successfully processed image: 8F885lcKzBQ
# Successfully processed image: aOZ0TDoduVc
# Successfully processed image: xhD49fKOzw0
# Skipping grayscale image: trZy8hkHEig
# Successfully processed image: 2QX4INtycDQ
# Successfully processed image: ZqZ45gvb1sg
# Successfully processed image: uP7LheisWcM
# Successfully processed image: E-6ZENGgngU
# Successfully processed image: jrZyQgKfq68
# Successfully processed image: GZ-pLuPZnz4
# Successfully processed image: rlU7qDGYPU8
# Successfully processed image: RFj0OkD0s18
# Successfully processed image: vwMBY66ED6Y
# Successfully processed image: p6slMrGDQSo
# Successfully processed image: zTzwCsh3EEw
# Successfully processed image: BKVBelJrG6I
# Successfully processed image: EzGKpiVsOhA
# Successfully processed image: tNhsb1k1jkE
# Successfully processed image: S9HQmqJGpxM
# Successfully processed image: ydTHYnRtaGA
# Successfully processed image: gcE6vwqOBjY
# Successfully processed image: AwMGRlipVzo
# Successfully processed image: dPziG30lYZ4
# Successfully processed image: Qjt01oQuEEw
# Successfully processed image: F_mQy6Z0vow
# Successfully processed image: Y9m1Z3Tl7XA
# Successfully processed image: AAmYBHqbAEs
# Successfully processed image: m-InFQ9clVU
# Successfully processed image: m16CRKJQAWo
# Successfully processed image: xkCP1OuOk7c
# Successfully processed image: POtl31yIzGo
# Successfully processed image: JUXulYgo78E
# Successfully processed image: 1_IV9CRLnd8
# Successfully processed image: cQY5cJ3R46s
# Successfully processed image: zo-c4LbkSM8
# Successfully processed image: jym3bkS7G-Y
# Successfully processed image: wzZJWkSofio
# Successfully processed image: AeqJWvRVI94
# Successfully processed image: bet7aRGHB4U
# Successfully processed image: 6uMh-02Nwj8
# Successfully processed image: C2UUFseZ8Lk
# Successfully processed image: iUGefrVAecs
# Successfully processed image: sLOxRwj5uT0
# Successfully processed image: rFWuAP0jdVs
# Successfully processed image: rmAK5hu7xsA
# Successfully processed image: Mq6j8q6n87s
# Successfully processed image: T9lmRSoGPKg
# Successfully processed image: Z0RptXj3fME
# Successfully processed image: -jJGKGSiwvs
# Successfully processed image: TpfbFAwZ3ZM
# Successfully processed image: onEC5llcpmY
# Successfully processed image: znKmV5D4BHg
# Successfully processed image: R-CrIoLU11M
# Successfully processed image: y0bCt2UwpvY
# Successfully processed image: IRfprajRcdk
# Successfully processed image: HIDkJoAE5kE
# Successfully processed image: VNGFoEkeiCM
# Successfully processed image: F8kVbIUIOZo
# Successfully processed image: Y7wZ2qRK0hM
# Successfully processed image: Sza0bpjd8gw
# Successfully processed image: E9YoQjLw6A4
# Successfully processed image: enEdaSOO5K8
# Successfully processed image: Ouxt6jBtrQ4
# Successfully processed image: ElMRqLN7P7A
# Successfully processed image: VWIESSJmfW8
# Successfully processed image: Qj0j1-yUhQk
# Successfully processed image: YP3Bn91omtk
# Successfully processed image: aFAzJ6IKE_M
# Successfully processed image: N3nFwJkR9jE
# Successfully processed image: ev0IgapSicM
# Successfully processed image: kZy1nlnf9Z8
# Successfully processed image: Ojdt_mSDk38
# Successfully processed image: QiDpfjDGRtc
# Successfully processed image: 2RYs4mRqbM4
# Successfully processed image: Szvrsk2DItU
# Successfully processed image: xnktiruwiM0
# Successfully processed image: 6W_3ojA3i84
# Successfully processed image: zCdiInvZcGw
# Successfully processed image: 0yNyDD2myzk
# Successfully processed image: 2F663tG1_dg
# Successfully processed image: m42Edn1pI7g
# Successfully processed image: SXc2-U8Nyss
# Successfully processed image: GEZ0FhIad1s
# Successfully processed image: Hc4_sJSqbOQ
# Successfully processed image: vlQGNIiCPfk
# Successfully processed image: s81oKOjpKlQ
# Successfully processed image: x_mRlyrsMzA
# Successfully processed image: Nr3lSVE43XA
# Successfully processed image: p7XocVlPUyg
# Successfully processed image: xBPL8IuVJkQ
# Successfully processed image: xgrOnk_i7xE
# Successfully processed image: XcZo3Zk-QUc
# Successfully processed image: i8ygGWtQzvY
# Successfully processed image: u1CYRNlTaWE
# Successfully processed image: -KxkDgEvWT8
# Successfully processed image: 7a1mxg3VbI0
# Skipping grayscale image: pa7YYVCq7k0
# Successfully processed image: 2sT1wre6vfU
# Successfully processed image: miBYxBjvAtw
# Successfully processed image: x1JnsqmKSVA
# Successfully processed image: jcYH_JE613I
# Successfully processed image: ft-iUOR0hi4
# Successfully processed image: hXSE3xI1y4w
# Successfully processed image: yHPTzPMFzSU
# Successfully processed image: 81tIDMsJrGg
# Successfully processed image: MYnhW-AYmQM
# Successfully processed image: FAbVOdITLZs
# Successfully processed image: i92q7QYl5AQ
# Successfully processed image: 5AyUHeSnxz8
# Successfully processed image: nqQ6Ski2uvw
# Successfully processed image: nB8Q_e35cFM
# Successfully processed image: 6PuUkY7u0mM
# Successfully processed image: GZi8gjGV76g
# Successfully processed image: dFDt1sy9z2M
# Successfully processed image: 3YbnpFS39oc
# Successfully processed image: k1kFlhjVry8
# Successfully processed image: 1rzZXCr0vFI
# Successfully processed image: OLC2nQUQhKA
# Successfully processed image: Qgb9urMZ8lw
# Successfully processed image: 3XWWFTKH2d4
# Successfully processed image: E_61iNM4uaQ
# Successfully processed image: P_DeR9_AuME
# Successfully processed image: 6F3ZfmKAwio
# Successfully processed image: 8hSaNgg0FR4
# Successfully processed image: x5lMhzgCDRE
# Successfully processed image: X_focRRR0Uw
# Successfully processed image: Lbu7p5_AGH8
# Successfully processed image: juq8dZOMD38
# Successfully processed image: 3iylzOqSXKA
# Successfully processed image: UDG_wELaYUM
# Successfully processed image: 2g4tPn43KQM
# Successfully processed image: BIzmgjskR6M
# Successfully processed image: 6HeIChA_8OY
# Successfully processed image: CnSQuQMoYIE
# Successfully processed image: id-lN41gs3U
# Successfully processed image: dLNkoL26LVI
# Successfully processed image: lrPBS8b4G14
# Successfully processed image: xlTolOtNLZM
# Successfully processed image: A6pK6vCywBg
# Successfully processed image: s79i3mBakbU
# Successfully processed image: 6GTlIs8tmfE
# Successfully processed image: VNW4XMbfkN4
# Successfully processed image: 1Z_BVuDS1h4
# Successfully processed image: LoiTMNlopsA
# Successfully processed image: AQ_Qu0ysWbw
# Successfully processed image: nKav_re96FA
# Successfully processed image: _RUWqZUIeqo
# Successfully processed image: 3SHAsRWNlUo
# Successfully processed image: 7_CM0-V4Uhk
# Successfully processed image: M5kI-5OFviE
# Successfully processed image: Ng9C-pVYZNY
# Successfully processed image: zgc0iHXHNnU
# Successfully processed image: r87uZZIh_yI
# Successfully processed image: Bjsx5y_nU3Q
# Successfully processed image: ip1LRG9rljg
# Successfully processed image: v-C-Bt4rGeY
# Successfully processed image: sFEDVau5xYg
# Successfully processed image: mFECC6AY67E
# Successfully processed image: IJDY2mghqe4
# Successfully processed image: J1t1FY__6EI
# Successfully processed image: SEXw8U_E-9o
# Successfully processed image: m_baK3-o0S8
# Successfully processed image: BQc-oQLkss4
# Successfully processed image: Bt_hazqan9c
# Successfully processed image: 17_tB-oI0ao
# Successfully processed image: mTzokuL_Gbs
# Successfully processed image: xW42e724p00
# Successfully processed image: 7MClrxZ8F6w
# Successfully processed image: ZkCVqkwlUGE
# Successfully processed image: nbklTnbXZ68
# Successfully processed image: 4O7OLWAPBOU
# Successfully processed image: kvd23GVL21c
# Successfully processed image: NX2vnTjGTVo
# Successfully processed image: EI4thy6TzEU
# Successfully processed image: 15J29EGlwmo
# Successfully processed image: rN3W0kwlETE
# Successfully processed image: 8se07e4kIDk
# Successfully processed image: hnzijjZAgIg
# Successfully processed image: ONWwYRelq_4
# Successfully processed image: Lbf8HVabEV0
# Successfully processed image: 4BEKjphtFd0
# Successfully processed image: pCSFyiKTBpE
# Successfully processed image: KrFvQ0J5TPg
# Successfully processed image: 30gyIWoLz3o
# Successfully processed image: fOeiC_rbBco
# Successfully processed image: k7oU5bHFDFE
# Successfully processed image: h48eaWQT11w
# Successfully processed image: pT9hJuvMMjI
# Successfully processed image: L3FHnmrPyCI
# Successfully processed image: DGyVvAJNyPE
# Successfully processed image: V63oM8OPJSo
# Successfully processed image: aOuy0kyXszo
# Successfully processed image: UIf9YO7LsuE
# Successfully processed image: vF9qIeQ-DI8
# Successfully processed image: rZ2LHT8eU9w
# Successfully processed image: StKbeSGn7To
# Successfully processed image: pC3T8Zub3mI
# Successfully processed image: 0rCO8xvW6tc
# Successfully processed image: YNUFtf4qyh0
# Successfully processed image: QP-6IYWN1Rg
# Successfully processed image: EE1B5Kvu6yg
# Successfully processed image: VIUcNPH9bu8
# Successfully processed image: 2OxmAcK3eXY
# Successfully processed image: BkTirGdBHy8
# Successfully processed image: mgQVhh493uw
# Successfully processed image: q6n8nIrDQHE
# Successfully processed image: B7mIW-x3g9s
# Successfully processed image: e8e2kOfEzOo
# Successfully processed image: SmhN4FejPFs
# Successfully processed image: cH5jDvYXwBo
# Successfully processed image: T26KCgCPsCI
# Successfully processed image: 6itktBSoYjo
# Successfully processed image: dfZbts6B4yw
# Successfully processed image: -u-utDdi6m0
# Successfully processed image: XmqsrSq63q4
# Successfully processed image: adIJfKDUg8Q
# Successfully processed image: cOzOIsKvsUQ
# Successfully processed image: Qw5jYjhQhmY
# Successfully processed image: x9RN-ZIzkf0
# Successfully processed image: 9U_uCvfpptk
# Successfully processed image: PXdBkNF8rlk
# Successfully processed image: vSsad4VVliw
# Successfully processed image: mibCiPnj-B8
# Successfully processed image: k_NkqIaRhro
# Successfully processed image: INf4LQZwxRU
# Successfully processed image: PyEFH3UWXOA
# Successfully processed image: wCujVcf0JDw
# Successfully processed image: QPg8RkHRIOo
# Successfully processed image: NSSsyfAQW2g
# Successfully processed image: I2SEp-d3J4w
# Successfully processed image: TtKZyFJ7XC0
# Successfully processed image: NVmgCHbgdx0
# Successfully processed image: ZaXS_O_Fedw
# Successfully processed image: FjvIsYAqoic
# Successfully processed image: pmwtvHNv-zM
# Successfully processed image: Shi_yFfqy9U
# Successfully processed image: rRESblStjRg
# Successfully processed image: tlxtycP51_U
# Successfully processed image: I3eKSkHXOG0
# Successfully processed image: yT1rgJxKFoM
# Successfully processed image: _7bJUC2WAXU
# Successfully processed image: 54TRXFqXZDk
# Successfully processed image: 2Q6V3bbV_uQ
# Successfully processed image: eOffmzHe2fA
# Successfully processed image: iS4pAzvxX74
# Successfully processed image: RLBPWIuQ6_E
# Successfully processed image: 7D9QH-rUnq0
# Successfully processed image: n4Tczn9hobM
# Successfully processed image: XzzRFJkIE5w
# Successfully processed image: aa1ktIrQv5I
# Successfully processed image: ZvPvViNfH3Y
# Successfully processed image: Hw0Y8xNH2uY
# Successfully processed image: fEFsgMqBifQ
# Successfully processed image: 1lF910N6uxc
# Successfully processed image: 9Kn4nEndOCY
# Successfully processed image: mN-_5ZQAt3M
# Successfully processed image: DlUyOdQxAlY
# Successfully processed image: 2X-6XZtCelM
# Successfully processed image: MEZEfc06GA0
# Successfully processed image: GfXUkvQ9XdY
# Successfully processed image: QjV0-62uGfA
# Successfully processed image: fsgxO2RyufU
# Successfully processed image: 3ODGln0xJV4
# Successfully processed image: 4unFXKGtCtI
# Successfully processed image: e4nypqfBD6M
# Successfully processed image: ll-Cj_GBia8
# Successfully processed image: W5MhJ6cy1So
# Successfully processed image: Ez5V2THOpDo
# Successfully processed image: EuSngguD40I
# Successfully processed image: Ub6-Ws5Q4-Y
# Successfully processed image: qj3PI0aDWks
# Successfully processed image: E9hVNb7wOY8
# Successfully processed image: wbkYwKstquI
# Successfully processed image: aWf0vy3iJfk
# Successfully processed image: efwGCPFdIcM
# Successfully processed image: bMHRz70Tcjg
# Successfully processed image: e-S-Pe2EmrE
# Successfully processed image: VrQRpV4c9jY
# Successfully processed image: Kctg1PLfAEU
# Successfully processed image: 4UexhWLVcnY
# Successfully processed image: BTjz5brgOc0
# Successfully processed image: J1VFDwSpASc
# Successfully processed image: d7oCsWZYpAk
# Successfully processed image: r8AdMFmtKho
# Successfully processed image: 404SG0er32k
# Successfully processed image: YNRTbN9IawU
# Successfully processed image: _fJD6NyUR8I
# Successfully processed image: B2ShPV9ixzY
# Successfully processed image: QFsdR1UAIfw
# Successfully processed image: dCpc8-VH4F4
# Successfully processed image: O59gXN46JgI
# Successfully processed image: OjffNmVYBpE
# Successfully processed image: UaSKd83CXsQ
# Successfully processed image: 2KcXQ_xMWcA
# Successfully processed image: GlHKd5I4SkY
# Successfully processed image: bjoxTUzLg1Q
# Successfully processed image: WE8mfKIPHpQ
# Successfully processed image: 63DhhZq03LI
# Successfully processed image: 2vDWKa2T1Y0
# Successfully processed image: UAin9f4XOP0
# Successfully processed image: 8xpklKrfsG4
# Successfully processed image: 5UFn4Ly4jwQ
# Successfully processed image: 2fFVsZjGZCg
# Successfully processed image: 2_3g53wNQk8
# Successfully processed image: MVCdr7m1pas
# Successfully processed image: IACtzClqfEA
# Successfully processed image: kCOxrCu2RwU
# Successfully processed image: 3AbwSH1y9dc
# Successfully processed image: EXdO9Z9Aof0
# Successfully processed image: 2kTJ7nZMa_s
# Successfully processed image: am7TTMSpT_k
# Successfully processed image: HvSQ_TBr7Ms
# Successfully processed image: Yh6K2eTr_FY
# Successfully processed image: P45gtJKufJo
# Successfully processed image: x3YAC7ig0vg
# Successfully processed image: xVwo6NxKDFk
# Successfully processed image: NMefBUONT3g
# Successfully processed image: 0PUQAOpLSIQ
# Successfully processed image: pQfAgConZVw
# Successfully processed image: 67sVPjK6Q7I
# Successfully processed image: OXF4xhRWQVo
# Successfully processed image: bPQdMRJ91u8
# Successfully processed image: OoqKykDmBXw
# Successfully processed image: Y-B3hOhzguw
# Successfully processed image: QqMYOkOdXmg
# Successfully processed image: 5htXZu3V3oM
# Successfully processed image: nDmw1-vml5k
# Successfully processed image: e_A1yNyDgrk
# Successfully processed image: iLvzn9WMwW8
# Successfully processed image: qnXiMkan_jk
# Successfully processed image: LFR9pA3i56E
# Successfully processed image: 90AZu3T0-kk
# Successfully processed image: hxn2HjZHyQE
# Successfully processed image: beWmEyK6KDk
# Successfully processed image: s9TJ2ncyLcQ
# Successfully processed image: SB0rxbS823g
# Successfully processed image: 4rezxlfTrGA
# Successfully processed image: U6mLK89hKNA
# Successfully processed image: rbupxkfFqSE
# Successfully processed image: v13b146Nz-A
# Successfully processed image: 0P3M35GDyk8
# Successfully processed image: 7ZiG0-YeFjU
# Successfully processed image: X6Gr8LBMvq4
# Successfully processed image: M_TF30BCXc8
# Successfully processed image: PEaGxHk2NWY
# Successfully processed image: pkEuxthQd1k
# Successfully processed image: XlcgYsU317E
# Successfully processed image: JdY-P44WBpY
# Successfully processed image: jr887Q5vi-s
# Successfully processed image: ptojCRijT3E
# Successfully processed image: czGBuGdu89s
# Successfully processed image: 8tem2WpFPhM
# Successfully processed image: zjy2yMUGzRU
# Successfully processed image: CIjUQRXCA34
# Successfully processed image: MZ4wcaMfALk
# Successfully processed image: UYrDYaXz85s
# Successfully processed image: GSs7lhq9uBI
# Successfully processed image: xhLYMOmoBWU
# Successfully processed image: oJieg2n8duk
# Successfully processed image: P0J-1ZaQzAM
# Successfully processed image: sTOYhbK0r_0
# Successfully processed image: S_IV6KqGeso
# Successfully processed image: 3B_NrzTjajc
# Successfully processed image: x2Miv4owGEM
# Successfully processed image: 02vspxvuZLo
# Successfully processed image: pKoKW6UQOuk
# Successfully processed image: aJMX4GyHjJ8
# Successfully processed image: Fw55DEkH6pg
# Successfully processed image: H-KXryoq2wE
# Successfully processed image: 7k1hBrAvK0w
# Successfully processed image: hw_Kp0BvxAM
# Successfully processed image: CQl3Y5bV6FA
# Successfully processed image: PB_SdlCPCDs
# Successfully processed image: _GJrk7Gj8lE
# Successfully processed image: X2WUR5hF3Rs
# Successfully processed image: o9Z91mK4Q5I
# Successfully processed image: bUhzlj3gGso
# Successfully processed image: RAdctHjxpfY
# Successfully processed image: zgujXJqyNqI
# Successfully processed image: wMNO1ikcIBc
# Successfully processed image: eyPiErJ6XcI
# Successfully processed image: QLmw7fMCDkg
# Successfully processed image: J6803ULieac
# Successfully processed image: P3PUwBUNnMA
# Successfully processed image: O_NpTrtdzx0
# Successfully processed image: Tf33w4dJglY
# Successfully processed image: SZs2dq_Y38w
# Successfully processed image: v1ySnKYCtrE
# Successfully processed image: l4MwmH8QIxk
# Successfully processed image: LJ3HxdRqlH0
# Successfully processed image: mSyTJIOClFI
# Successfully processed image: 4Q1Yu2c5EXA
# Successfully processed image: F-MppUAwM18
# Successfully processed image: J9L1jMXRvZA
# Successfully processed image: M34IAftLLsY
# Successfully processed image: xAns8H5j9rM
# Successfully processed image: yK43IdBQsio
# Skipping grayscale image: n1bbNrNSJH8
# Successfully processed image: egszj09jbJ0
# Successfully processed image: -Ep46FW5-2k
# Successfully processed image: 1-SgkezDA_s
# Successfully processed image: 9bybELtYylc
# ...
# Successfully processed image: eF2MdCCNE7M
# Successfully processed image: Tz4ClhSLlBU
# Successfully processed image: Y6oFLC-KnEA
# Successfully processed image: 78tmVu2BQXk
# Successfully processed image: eDAVQYX5YBQ
# Successfully processed image: EheKbIZ8oAw
# Successfully processed image: 9RMUiIz8at8
# Successfully processed image: rtCujH697DU
# Successfully processed image: WzOvRQ4aQJM
# Successfully processed image: ZqTW0r33Bg0
# Successfully processed image: eJN9bcqZGWU
# Successfully processed image: LGyabE_ELAU
# Successfully processed image: EDMfACDDgZY
# Skipping grayscale image: 44bnJHgXKU4
# Successfully processed image: dSB_QwlCpRs
# Successfully processed image: e7W6BYt6Pjg
# Successfully processed image: OR4q9_Y2nuY
# Successfully processed image: 6ZQW6zSRBYI
# Successfully processed image: oCqamP96fWE
# Successfully processed image: FpCgVhP_p-c
# Successfully processed image: Q03M_Z6YG7c
# Successfully processed image: UzEf18WCkro
# Successfully processed image: cRK5zOhFVBk
# Successfully processed image: 7C7qxpf2xAg
# Successfully processed image: tjhRuXnTBoI
# Successfully processed image: xYzqDr0DBNw
# Successfully processed image: bKFmjetkghk
# Successfully processed image: bVOKzG9zSek
# Successfully processed image: YnMgsRsfS50
# Successfully processed image: 0O9A0F_d1qA
# Successfully processed image: qKlO-lXq9Oo
# Successfully processed image: FzPvoW6HHwk
# Successfully processed image: 9NK-gKbHd1Q
# Successfully processed image: 0o3Cfq6WJ6Y
# Successfully processed image: wD9VImVnTqM
# Successfully processed image: 2XLuMShTV-M
# Successfully processed image: 0iNLhORjMGM
# Successfully processed image: 1-vouQEaHOA
# Successfully processed image: -zpu-sU2g-0
# Successfully processed image: v6eA2IbLD3w
# Successfully processed image: F1F84QlcxZ8
# Successfully processed image: XhCLdQ44d1o
# Successfully processed image: YkMkngYOo4w
# Successfully processed image: NUTYDyjfB4c
# Successfully processed image: N_Xa7H4YzFY
# Successfully processed image: 3l43HYrFDEI
# Successfully processed image: OuYESbJjiW0
# Successfully processed image: cTEFCekvecI
# Successfully processed image: H8N4Qsbdn6I
# Successfully processed image: NklUjoSBY-E
# Successfully processed image: G8T5Jb6ZMjQ
# Successfully processed image: fEUlRjbtOPY
# Successfully processed image: m5q-ZpD7t04
# Successfully processed image: 7DpEKohpOhQ
# Successfully processed image: POAwEm4MgMo
# Successfully processed image: SaovgEQMo00
# Successfully processed image: I7svaesZ2fE
# Successfully processed image: aGX9ypwhhXA
# Successfully processed image: fgViiCEzdyw
# Successfully processed image: DMnHQUitTQU
# Successfully processed image: jV7Wdu7GjsQ
# Successfully processed image: NEg-_wWMa0k
# Successfully processed image: RYIgYuwFTrA
# Successfully processed image: 1Vb2b02D1UE
# Successfully processed image: 5Cxh8L6Gj18
# Successfully processed image: EKhRc_ymjh0
# Successfully processed image: frzHLsysu5s
# Successfully processed image: I84tlLmvRJQ
# Successfully processed image: sBZGuKJVHcY
# Successfully processed image: Kp-SF408cBA
# Successfully processed image: _MtntMqsVOQ
# Successfully processed image: dCfagb2y28M
# Successfully processed image: VLOpw_F9iC8
# Successfully processed image: ILz31HBGEak
# Successfully processed image: M4I_e5_z5Ww
# Successfully processed image: o7Pvh_OKjeg
# Successfully processed image: GVH4jF5LGuQ
# Successfully processed image: Q47I_dCsNyY
# Successfully processed image: wud-eV6Vpwo
# Successfully processed image: Zb-3DcfHlfI
# Successfully processed image: PaZjj8jC-Tg
# Successfully processed image: 2EDjes2hlZo
# Successfully processed image: Cwo4iiZ5eDY
# Successfully processed image: 8UXhQkhTEEc
# Successfully processed image: a4yUBzhnuO0
# Successfully processed image: AORWsJS39ag
# Successfully processed image: T0UsMfZVVDQ
# Successfully processed image: 2sHW5kPSOG8
# Successfully processed image: c2tsGuLi1kc
# Successfully processed image: od5r1Dus0TE
# Successfully processed image: rwvoWJlMkIs
# Successfully processed image: iIYoeZKNQtU
# Successfully processed image: PkZzygxIxk0
# Successfully processed image: Xu1xO3mpr1I
# Successfully processed image: 7hI6SQjk4Yc
# Successfully processed image: X0SMdQSQwzc
# Successfully processed image: iVB_P7pn2eY
# Successfully processed image: KlyZGkmE01w
# Successfully processed image: cnO9IQzhUbI
# Successfully processed image: QPvrefd5TXg
# Successfully processed image: NLOWG9Zm01w
# Successfully processed image: 6cQ9E0AbwOo
# Successfully processed image: t_pbXwIjK-g
# Successfully processed image: XYFpx1ErGOU
# Successfully processed image: 4OLiKJ48ADY
# Successfully processed image: v08FVc-stIs
# Successfully processed image: dbrE_Nc6L4M
# Successfully processed image: QUx1qvBS7EY
# Successfully processed image: qGcjXMfh0jw
# Successfully processed image: VnHGhoPXzD8
# Successfully processed image: AEZEx7encQs
# Successfully processed image: 2xf2beBy7Wo
# Successfully processed image: gXdOzkFq-74
# Successfully processed image: CHs2E34Xve0
# Successfully processed image: BU1RL_2rA4w
# Successfully processed image: 2y4X0a-ygJo
# Successfully processed image: vV_uStz1_YQ
# Successfully processed image: 2TivgHgF8AE
# Successfully processed image: Z43yOLLYhas
# Successfully processed image: U_5ePt5_IaU
# Successfully processed image: iwDd0BEw7z4
# Successfully processed image: 1GxT-yz-PGQ
# Successfully processed image: bJHWJeiHfHc
# Successfully processed image: LZpzMEY0pXI
# Successfully processed image: PwjPYvRWf2Y
# Successfully processed image: Ef7C4bPDL4A
# Successfully processed image: kuT7X8djcMM
# Successfully processed image: uCTlqRpsv5c
# Successfully processed image: hP7sLLnrlKg
# Successfully processed image: w58L5M2IAm0
# Successfully processed image: cyTb5Qrs-ko
# Successfully processed image: CMdQcxsWZE0
# Successfully processed image: rIDE73mqi2s
# Successfully processed image: Rs82ubSF-8M
# Successfully processed image: bzEfpDMVQzs
# Successfully processed image: bUTw0JyBmAI
# Successfully processed image: bWssU2C3LSI
# Successfully processed image: lLctqdwTYes
# Successfully processed image: _LLcIlMoUaE
# Successfully processed image: mR_HR8NZwg8
# Successfully processed image: eonAf_JQFbI
# Successfully processed image: O_uV3KhQuo8
# Successfully processed image: RueSVa1rAJc
# Successfully processed image: vpAKO21abME
# Successfully processed image: GdOvl0W2msk
# Successfully processed image: -wPKYv1kQrA
# Successfully processed image: JACEkXaAay0
# Successfully processed image: SAcIANM1zgI
# Successfully processed image: 5YvHy6-O5bU
# Successfully processed image: 7wk0ja-DP_c
# Successfully processed image: SdG5KmRFZNI
# Successfully processed image: EmXc_zG5U9A
# Successfully processed image: SYM9t8j4iE8
# Successfully processed image: gyH7JOPbVJg
# Successfully processed image: ffODvgBivdw
# Successfully processed image: xOZhdQXNfZI
# Successfully processed image: xfgeMfYFsMk
# Successfully processed image: LzbGdOThrr0
# Successfully processed image: kFucQoKaQ3g
# Successfully processed image: dOqQjP_qohA
# Successfully processed image: F0cRGow_Sck
# Successfully processed image: Cl8iDlk008c
# Successfully processed image: CWLNJqPSml4
# Successfully processed image: Dq2bns-Fw6g
# Successfully processed image: MpIoPBR42qg
# Successfully processed image: 4GVe6DC-ADA
# Successfully processed image: ZZYaTMuxFwg
# Successfully processed image: Wd-a5H3PK6k
# Successfully processed image: wDLnCaHHrKU
# Successfully processed image: ls4OK8rINvc
# Successfully processed image: 8m8sQVZPAKg
# Successfully processed image: sDt4NczMXAw
# Successfully processed image: ZP7Gg5m69Vg
# Successfully processed image: 5XEi4zfliX4
# Successfully processed image: 6mei_aaJZmg
# Successfully processed image: w6eLyP1Ib9M
# Successfully processed image: AFKOugrPThg
# Successfully processed image: oiDC6fDtr3k
# Successfully processed image: 7uQrE2W02hM
# Successfully processed image: ARVFsI-32Uk
# Successfully processed image: 8PppxyQr7QI
# Successfully processed image: EFoDbpGsGHk
# Successfully processed image: YNteh8tG_RE
# Successfully processed image: B7TDIipUuas
# Successfully processed image: wMwbm8zdTyU
# Successfully processed image: -KUD807lwSo
# Successfully processed image: g9Px49-lNks
# Successfully processed image: yGKQKaKzcuA
# Successfully processed image: JdjmjwnwJIY
# Successfully processed image: m-ZemAIkXlE
# Successfully processed image: 3JcFnHLSMP8
# Successfully processed image: imUKS9r3_2Q
# Successfully processed image: YxMJOBnnmHA
# Successfully processed image: x1noB3hon_Q
# Successfully processed image: droDU1dQviA
# Successfully processed image: yLympaD0S4I
# Successfully processed image: 7mT2N0Wwzk0
# Successfully processed image: cujzXuKmHwI
# Successfully processed image: ptp1UHJ6c5M
# Successfully processed image: P0SbmtjxsZc
# Successfully processed image: LwxSvPXrJFs
# Successfully processed image: OMw5wiCCwTA
# Successfully processed image: wEAwiEecwHs
# Successfully processed image: gHN5fIX6k34
# Successfully processed image: xdRhYLrRqiU
# Successfully processed image: _84S1gXSeZM
# Successfully processed image: zuQzOWzzQv8
# Successfully processed image: 7oGIKVNjPx0
# Successfully processed image: nQux4nTsMuQ
# Successfully processed image: ghJHlcAsT1w
# Successfully processed image: TcRk4MDuLF4
# Successfully processed image: bM95unm7O5U
# Successfully processed image: MVKYxT3VB3A
# Successfully processed image: ly3tKhWfQ34
# Successfully processed image: _EvjXFVM9pw
# Successfully processed image: 9aZkkMUJAJU
# Successfully processed image: Dcvco7sYQwk
# Successfully processed image: vRvVvjl5Z0k
# Successfully processed image: _ihGttRnT_I
# Successfully processed image: HYt4uBkjr_4
# Successfully processed image: cUaXzFXVKkA
# Successfully processed image: gPVK0VIjKcA
# Successfully processed image: cjO4_06pkSM
# Successfully processed image: Vw6PwmjrtiE
# Successfully processed image: CwZjanxsCvs
# Successfully processed image: 0VD9TGRVrBs
# Successfully processed image: 9LEogrMVMwY
# Successfully processed image: IyAmVX9y8Iw
# Successfully processed image: y9iVVYJlSB8
# Successfully processed image: me0hi86szok
# Successfully processed image: s9w9L0V8L9U
# Successfully processed image: 0M98PE0Cef8
# Successfully processed image: XScEdhZAHv0
# Skipping grayscale image: lma-UBA4LEk
# Successfully processed image: mf8A3tpVWPU
# Successfully processed image: FN_ADaWg14E
# Successfully processed image: 7pMTQP_kIhg
# Successfully processed image: tno_aO7NKIw
# Successfully processed image: _CXlQkqZhkk
# Successfully processed image: oa8vRa1JBlw
# Successfully processed image: jX-evyJ8OPc
# Successfully processed image: Xaf5RUAsiwU
# Successfully processed image: xt2RVBBO6uI
# Successfully processed image: KgxGR2ws0BA
# Successfully processed image: DqIyKlJa-2s
# Successfully processed image: 7ONomtIMf1k
# Successfully processed image: bq6Gd7pQznU
# Successfully processed image: VWSLAzov1Qc
# Successfully processed image: 5SXWtuSz2gc
# Successfully processed image: n9Jy8B5MzEo
# Successfully processed image: izqJ2_I5yhc
# Successfully processed image: tBSAoST2YW0
# Successfully processed image: q2uNh877S4s
# Successfully processed image: PW7ZYRBGSj0
# Successfully processed image: dA1BN6_qGCw
# Successfully processed image: xljjB3E2C5M
# Successfully processed image: uj9luvxULuY
# Successfully processed image: QwJ_L9L5eOw
# Successfully processed image: v0_uaaxl7xo
# Successfully processed image: x1QSu6XexIw
# Successfully processed image: 1MjCYK1rKQc
# Successfully processed image: bgw5HDiGzt0
# Successfully processed image: rXo51TSGKkg
# Successfully processed image: fk1B5UQn0U0
# Successfully processed image: rsQ6e9d8GeY
# Successfully processed image: Xf6JnoD0Hss
# Successfully processed image: 8MD_TrUkzbU
# Successfully processed image: nXNORZnWu5s
# Successfully processed image: AxdlcxaModc
# Successfully processed image: ubA4MSQh9Po
# Successfully processed image: biHCJxTeo9k
# Successfully processed image: WfMObe47oMQ
# Successfully processed image: _5PyWBp9HqA
# Successfully processed image: IcOn1qzoTHE
# Successfully processed image: F5ypWjjulqw
# Successfully processed image: CaZ5FoxvZGE
# Successfully processed image: W2ReRcbVZbY
# Successfully processed image: 6cplDi5aou4
# Successfully processed image: mq8Y9FYFZ24
# Successfully processed image: S-5qu7iwQfc
# Successfully processed image: -6hvB84fyYA
# Successfully processed image: S3G8qX4Ft5s
# Successfully processed image: 3DoNWvj2xXQ
# Successfully processed image: VQIyVId7APM
# Successfully processed image: eH92ydifeD0
# Successfully processed image: uR_pNOruRPk
# Successfully processed image: MJ7602o8vIc
# Successfully processed image: GMUNAVOgp38
# Successfully processed image: 3JQbGLh17Gw
# Successfully processed image: x4ABZUkeJg8
# Successfully processed image: flfhAlEwDq4
# Successfully processed image: TSCmBAopokA
# Successfully processed image: s4jRjoJDLFw
# Successfully processed image: xpVh9nbRcWw
# Successfully processed image: ykk25W6Tiyw
# Successfully processed image: mFTAV-eoLOU
# Successfully processed image: HZlIfvYRWDk
# Successfully processed image: HJDNLHom44I
# Successfully processed image: Lwqv4tEIKOU
# Successfully processed image: QLCw6TUQG_k
# Successfully processed image: NuvDThdGUi4
# Successfully processed image: LwRUp8vJJI8
# Successfully processed image: DRMkkgMMHk4
# Successfully processed image: RsDH_BgoKQ0
# Successfully processed image: NUcNh9PcYg4
# Successfully processed image: Xtz44YgyrK4
# Successfully processed image: 2fIxy1Z--OY
# Successfully processed image: AqNyevKDJdo
# Successfully processed image: yFyFFZv6F4c
# Successfully processed image: ne7xzMgfrnY
# Successfully processed image: lcmJ4F4gDI0
# Successfully processed image: ccIFF34z-6Q
# Successfully processed image: 2qXNT7LMfpY
# Successfully processed image: yGQjaO0Th2o
# Successfully processed image: 03CBKvuP-48
# Skipping grayscale image: UoZ_YPICC1s
# Successfully processed image: pI0xpRUO_TM
# Successfully processed image: -Y1dcU9sGO0
# Successfully processed image: MIfic5MC6jY
# Successfully processed image: S1i0HO2RyXs
# Successfully processed image: k1QqUSvRObc
# Successfully processed image: beCmoefmrEc
# Successfully processed image: ZLuscixku-I
# Successfully processed image: LKM_-dS9VQ8
# Successfully processed image: EzUJ06Kw278
# Successfully processed image: W2ZPTqdD1u4
# Successfully processed image: jlwAIT6Cy0o
# Successfully processed image: cQCwbC_nciw
# Successfully processed image: eAbgjvMA7Z8
# Successfully processed image: RD_A6yx-NN8
# Successfully processed image: iGmK8yw_oGc
# Successfully processed image: iuhLxpgSAuA
# Successfully processed image: iDGoa4OY5So
# Successfully processed image: 4ZhQkF12CQ0
# Successfully processed image: UFFSWh7tcYc
# Successfully processed image: wZWLVSxxQ-8
# Successfully processed image: gr8r8bfJZtE
# Successfully processed image: q1uiITCnFfY
# Successfully processed image: sVhWVEX8zFA
# Successfully processed image: EUe2SORHrQk
# Successfully processed image: -8qcWyVHCDY
# Successfully processed image: fpr4wdEWFDY
# Successfully processed image: jh3ImbLsq7U
# Successfully processed image: rx5Dupt07Q4
# Successfully processed image: 1rf6BLoYOWE
# Successfully processed image: PfuKfT9FpEE
# Successfully processed image: bO2MULV1MBU
# Successfully processed image: WtzeA5u_HN0
# Successfully processed image: r17CwjZBOc8
# Successfully processed image: 8-cqlcHZF9o
# Successfully processed image: hYrNfVa0xU4
# Successfully processed image: 21BKeE0Oo40
# Successfully processed image: ts7R37V-gPM
# Successfully processed image: ALEEHvhQnyE
# Successfully processed image: KBqiQ6coMcI
# Successfully processed image: G4DS3bk707U
# Successfully processed image: ypPbS6NNHkA
# Successfully processed image: FcUplYOKnak
# Successfully processed image: rmt_Wt1DE-g
# Successfully processed image: 6MS5lQ31rd4
# Successfully processed image: Z15VEca6eB8
# Successfully processed image: VLxoElrtQOE
# Successfully processed image: b9lPdPUgeV4
# Successfully processed image: mZabJ9h8_jc
# Successfully processed image: KkRxQa8LwmM
# Successfully processed image: xwB4uklpI3o
# Successfully processed image: Bc41iMx5RRQ
# Successfully processed image: FEH5YWGZF1U
# Successfully processed image: yYdFmqK2UfY
# Successfully processed image: 7Y_Hiv-GzXQ
# Skipping grayscale image: 43h0R5Q-2aM
# Successfully processed image: NIz7SKse_wQ
# Successfully processed image: vGLS-6oycoI
# Successfully processed image: 0Hr2m3V_w1Q
# Successfully processed image: E9in-VM5F8s
# Successfully processed image: rZQq3bdOsJU
# Successfully processed image: swQ3JS8e-Fs
# Skipping grayscale image: pZroun8cH1w
# Successfully processed image: JqOvq9ypB4w
# Successfully processed image: DItZ9r6Pt30
# All images processed successfully!

# %% [markdown]
# ### Create augmented versions of the downloaded images

# %%
import os
import cv2
import numpy as np
import albumentations as A
from albumentations.core.composition import ReplayCompose

# %%
# Paths
original_rgb_path = "../data/Unsplash/Images/RGB"
output_base_path = "../data/Unsplash/Images/Augmented"
log_file_path = os.path.join(output_base_path, "error_log.txt")

os.makedirs(os.path.join(output_base_path, "RGB"), exist_ok=True)
os.makedirs(os.path.join(output_base_path, "L"), exist_ok=True)
os.makedirs(os.path.join(output_base_path, "A"), exist_ok=True)
os.makedirs(os.path.join(output_base_path, "B"), exist_ok=True)

# Define augmentation pipeline with ReplayCompose
augmentations = ReplayCompose([
    A.HorizontalFlip(p=0.5),
    A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=15, border_mode=cv2.BORDER_REFLECT, p=0.5),
    A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5),
    A.GaussianBlur(blur_limit=(3, 7), p=0.3),
    A.Resize(256, 256),  # Ensure output remains 256x256
])

# Initialize counter
image_counter = 0

# Process each image
for filename in os.listdir(original_rgb_path):
    if not filename.endswith(".png"):
        continue

    base_filename = filename.replace(".png", "")

    # Load the original RGB image
    input_path = os.path.join(original_rgb_path, filename)
    rgb_image = cv2.imread(input_path, cv2.IMREAD_COLOR)
    if rgb_image is None:
        with open(log_file_path, "a") as log_file:
            log_file.write(f"Could not load image: {input_path}\n")
        continue

    try:
        for i in range(1, 3):  # Generate 2 augmentations per image
            augmented = augmentations(image=rgb_image)
            augmented_rgb = augmented["image"]

            # Generate file paths for augmented versions
            augmented_rgb_path = os.path.join(output_base_path, "RGB", f"{base_filename}_aug{i}.png")
            l_augmented_path = os.path.join(output_base_path, "L", f"{base_filename}_aug{i}.png")
            a_augmented_path = os.path.join(output_base_path, "A", f"{base_filename}_aug{i}.png")
            b_augmented_path = os.path.join(output_base_path, "B", f"{base_filename}_aug{i}.png")

            # Convert augmented RGB to LAB and split channels
            augmented_lab = cv2.cvtColor(augmented_rgb, cv2.COLOR_BGR2LAB)
            l_augmented, a_augmented, b_augmented = cv2.split(augmented_lab)

            # Save all augmented versions
            cv2.imwrite(augmented_rgb_path, augmented_rgb)
            cv2.imwrite(l_augmented_path, l_augmented)
            cv2.imwrite(a_augmented_path, a_augmented)
            cv2.imwrite(b_augmented_path, b_augmented)

        image_counter += 1
        if image_counter % 10 == 0:
            print(f"Augmented and saved {image_counter} images so far.")

    except Exception as e:
        # Cleanup in case of errors
        with open(log_file_path, "a") as log_file:
            log_file.write(f"Error processing {filename}: {e}\n")

        for i in range(1, 3):  # Ensure all generated versions for this file are deleted
            for path in [
                os.path.join(output_base_path, "RGB", f"{base_filename}_aug{i}.png"),
                os.path.join(output_base_path, "L", f"{base_filename}_aug{i}.png"),
                os.path.join(output_base_path, "A", f"{base_filename}_aug{i}.png"),
                os.path.join(output_base_path, "B", f"{base_filename}_aug{i}.png")
            ]:
                if os.path.exists(path):
                    os.remove(path)

print("All images have been augmented and saved.")

# %% [markdown]
# ### Train-Validation-Test Split

# %%
# Download data, split to train test val

import os
import shutil
import random
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Google Drive and Colab VM paths
drive_base_path = "/content/drive/MyDrive/Okul/Eğitim/Ders/5. Dönem/YZV 303E - Deep Learning/Project/data/Unsplash/Images"
local_base_path = "/content/Unsplash/Images"
split_base_path = "/content/TrainTestVal"

# Create local folders
os.makedirs(local_base_path, exist_ok=True)
os.makedirs(split_base_path, exist_ok=True)

# Step 1: Copy L, A, B, and Augmented folders from Google Drive to Colab
folders_to_copy = ["L", "A", "B", "Augmented/L", "Augmented/A", "Augmented/B"]
for folder in folders_to_copy:
    src_path = os.path.join(drive_base_path, folder)
    dest_path = os.path.join(local_base_path, folder)
    os.makedirs(dest_path, exist_ok=True)
    print(f"Copying {folder} from Google Drive...")
    shutil.copytree(src_path, dest_path, dirs_exist_ok=True)
print("All folders copied successfully!")

# Step 2: Gather all files from L (original and augmented)
l_original_files = [os.path.join(local_base_path, "L", f) for f in os.listdir(os.path.join(local_base_path, "L")) if f.endswith('.png')]
l_augmented_files = [os.path.join(local_base_path, "Augmented/L", f) for f in os.listdir(os.path.join(local_base_path, "Augmented/L")) if f.endswith('.png')]
all_l_files = l_original_files + l_augmented_files

# Ensure consistency for A and B
def get_corresponding_files(base_files, channel):
    corresponding_files = []
    for file_path in base_files:
        if "Augmented" in file_path:
            corresponding_files.append(file_path.replace("Augmented/L", f"Augmented/{channel}"))
        else:
            corresponding_files.append(file_path.replace("/L/", f"/{channel}/"))
    return corresponding_files

all_a_files = get_corresponding_files(all_l_files, "A")
all_b_files = get_corresponding_files(all_l_files, "B")

# Step 3: Reduce dataset size to 20K files
random.seed(42)
selected_indices = random.sample(range(len(all_l_files)), min(len(all_l_files), 20000))
selected_l_files = [all_l_files[i] for i in selected_indices]
selected_a_files = [all_a_files[i] for i in selected_indices]
selected_b_files = [all_b_files[i] for i in selected_indices]

# Step 4: Train-Test-Validation split
train_l, test_l, train_a, test_a, train_b, test_b = train_test_split(selected_l_files, selected_a_files, selected_b_files, test_size=0.2, random_state=42)
train_l, val_l, train_a, val_a, train_b, val_b = train_test_split(train_l, train_a, train_b, test_size=0.2, random_state=42)

# Step 5: Copy files into TrainTestVal directories
def copy_split_files(file_list, split_name, channel):
    split_folder = os.path.join(split_base_path, split_name, channel)
    os.makedirs(split_folder, exist_ok=True)
    for file_path in tqdm(file_list, desc=f"Copying {split_name} {channel} files"):
        shutil.copy(file_path, split_folder)

splits = [("Train", train_l, train_a, train_b), ("Val", val_l, val_a, val_b), ("Test", test_l, test_a, test_b)]
for split_name, l_files, a_files, b_files in splits:
    copy_split_files(l_files, split_name, "L")
    copy_split_files(a_files, split_name, "A")
    copy_split_files(b_files, split_name, "B")

print("Train, Val, and Test splits created successfully!")

# %%
# Zip the TrainTestVal and upload to Google Drive

import os
import shutil

# Paths
local_train_test_val_path = "/content/TrainTestVal"
drive_destination_path = "/content/drive/MyDrive/Okul/Eğitim/Ders/5. Dönem/YZV 303E - Deep Learning/Project/data/TrainTestVal.zip"

# Step 1: Zip the TrainTestVal folder
zip_file_path = "/content/TrainTestVal.zip"
print("Zipping TrainTestVal folder...")
shutil.make_archive(base_name=zip_file_path.replace(".zip", ""), format="zip", root_dir=local_train_test_val_path)
print("Zipping complete!")

# Step 2: Copy the zipped file to Google Drive
print("Copying TrainTestVal.zip to Google Drive...")
shutil.copy(zip_file_path, drive_destination_path)
print(f"Copied TrainTestVal.zip to {drive_destination_path}")

# Step 3: Confirm the file exists in Google Drive
if os.path.exists(drive_destination_path):
    print("TrainTestVal.zip successfully saved in Google Drive!")
else:
    print("Failed to copy TrainTestVal.zip to Google Drive.")

# %%
# Zip the whole Unsplash data and upload to drive

import os
import shutil

# Paths
local_images_path = "/content/Unsplash"
drive_destination_path = "/content/drive/MyDrive/Okul/Eğitim/Ders/5. Dönem/YZV 303E - Deep Learning/Project/data/Unsplash.zip"

# Step 1: Zip the TrainTestVal folder
zip_file_path = "/content/Unsplash.zip"
print("Zipping Unsplash folder...")
shutil.make_archive(base_name=zip_file_path.replace(".zip", ""), format="zip", root_dir=local_images_path)
print("Zipping complete!")

# Step 2: Copy the zipped file to Google Drive
print("Copying Unsplash.zip to Google Drive...")
shutil.copy(zip_file_path, drive_destination_path)
print(f"Copied Unsplash.zip to {drive_destination_path}")

# Step 3: Confirm the file exists in Google Drive
if os.path.exists(drive_destination_path):
    print("Unsplash.zip successfully saved in Google Drive!")
else:
    print("Failed to copy Unsplash.zip to Google Drive.")
# Out:
# Zipping Unsplash folder...
# Zipping complete!
# Copying Unsplash.zip to Google Drive...
# Copied Unsplash.zip to /content/drive/MyDrive/Okul/Eğitim/Ders/5. Dönem/YZV 303E - Deep Learning/Project/data/Unsplash.zip
# Unsplash.zip successfully saved in Google Drive!
